# %%
# to do:

# unsigned?

# %% [markdown]
# # c Read Input Arguments (args)
#
# u% is for unsigned...
#
# https://stackoverflow.com/questions/523237/how-to-read-in-numbers-as-command-arguments
#
# https://stackoverflow.com/questions/27260304/equivalent-of-atoi-for-unsigned-integers#27278489
#
#
# ```
# atoi()
#
# convert string to long
# strtol()
#
# unsigned integers
# strtoul()
# ```
#
# unsigned long int strtoul(const char *nptr, char **endptr, int base);

# %% [markdown]
# # Install

# %%
! sudo apt install splint

! pip install cpplint
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   splint-data
# Suggested packages:
#   splint-doc-html
# The following NEW packages will be installed:
#   splint splint-data
# 0 upgraded, 2 newly installed, 0 to remove and 20 not upgraded.
# Need to get 740 kB of archives.
# After this operation, 2,883 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 splint-data all 1:3.1.2+dfsg-1build1 [57.5 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 splint amd64 1:3.1.2+dfsg-1build1 [683 kB]
# Fetched 740 kB in 1s (572 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 2.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package splint-data.
# (Reading database ... 155676 files and directories currently installed.)
# Preparing to unpack .../splint-data_1%3a3.1.2+dfsg-1build1_all.deb ...
# Unpacking splint-data (1:3.1.2+dfsg-1build1) ...
# Selecting previously unselected package splint.
# Preparing to unpack .../splint_1%3a3.1.2+dfsg-1build1_amd64.deb ...
# Unpacking splint (1:3.1.2+dfsg-1build1) ...
# Setting up splint-data (1:3.1.2+dfsg-1build1) ...
# Setting up splint (1:3.1.2+dfsg-1build1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting cpplint
#   Downloading cpplint-1.6.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 3.6 MB/s
# Installing collected packages: cpplint
# Successfully installed cpplint-1.6.1

# %% [markdown]
# # Make demo.csv

# %%
"""
Make csv file.
"""


#########################
# Text for demo.csv file
#########################
c_source_code_string = """
/*
c program to write a sample demo dummy .csv file

https://www.geeksforgeeks.org/strings-in-c-2/
*/

#include <stdio.h>
#include <stdlib.h>

int main() {

    // set variable/memory for dummy csv file
    char str[100] = "a,b,c\\n1,2,3\\n4,5,6";


    // creating file pointer to work with files
    FILE *file_pointer;


    // opening file in writing mode
    file_pointer = fopen( "demo.csv", "w" );


    // check for error: was file created? if not exit program with message.
    if ( file_pointer == NULL ) {
        printf( "The Error! The Error! AHHHHHHHH!!!!!" );
        exit( 1 );
    }

    // write to file
    fprintf( file_pointer, "%s", str );
    

    // close file, ending file-write
    fclose( file_pointer );
    

    // end program, exit
    return 0;
}
"""

####################################
# make it: Make your .c source file
####################################
with open('source_file.c', "w") as file_object:
   # write file content
   file_object.write( c_source_code_string )

#################################
# Compile your c executible file
#################################

! gcc -o executable.exe source_file.c

##########################################
# List Files in Current Working Directory
##########################################
# !ls

#################################
# Run your c executible file
#################################

# !./executable.exe
# Out:
# executable.exe	sample_data  source_file.c

# %% [markdown]
# # C Source Code

# %%
c_source_code_string = """/*
bitwise

GGAshbrook 2022.08.21

"Copyright [year] <Copyright Owner>"  [legal/copyright]"
*/

#include <stdio.h>
#include <stdlib.h>
#include <string.h>

int main(int argc, char **argv) {
      ////////////
     // variables
    /////////////

    unsigned int first_number_input;
    unsigned int second_number_input;
    unsigned int the_answer;


      ///////////////////////////
     // Check and Set Variables int arg1 = atoi(argv[1]);
    ///////////////////////////

    // check length of input
    if ( argc != 3 ) {
        // Error message in English
        printf("argc = %d", argc);
        printf("incorrect number of input arguments: ");
        printf("After NAME.exe -> enter: ");
        printf("1. first number (int), 2. second number (int)");

        return EXIT_FAILURE;
        }

    // second input is the target row
    // pseudocode: first_number_input = argv[2]
    sscanf(argv[1], "%u", &first_number_input);

    // third input is the target column
    // pseudocode: second_number_input = argv[3]
    sscanf(argv[2], "%u", &second_number_input);


      /////////
     // Code
    /////////

    the_answer = first_number_input | second_number_input;


      ////////////
     // Print //
    ////////////

    printf("| the_answer = %u", the_answer);


      ////////////
     // Finish //
    ////////////

    return 0;
}
"""

####################################
# Make it: Make your .c source file
####################################
with open('main.c', "w") as file_object:
   # write file content
   file_object.write( c_source_code_string )

#################################
# Compile your c executible file
#################################
# inspection
print("Compile: ")

# !gcc -o program.exe main.c

##########################################
# List Files in Current Working Directory
##########################################

# inspection
print("\nList Files (ls): ")

# !ls

#############################
# Run your c executible file
#############################
# inspection
print("\nRun: ")

# !./program.exe 5 12
# Out:
# Compile:
#
# List Files (ls):
# demo.csv  executable.exe  main.c  program.exe  sample_data  source_file.c
#
# Run:
# | the_answer = 13

# %%
c_source_code_string = """/*
bitwise

GGAshbrook 2022.08.21

"Copyright [year] <Copyright Owner>"  [legal/copyright]"
*/

#include <stdio.h>
#include <stdlib.h>
#include <string.h>

int main(int argc, char **argv) {
      ////////////
     // variables
    /////////////

    unsigned int input_1;
    unsigned int input_2;
    unsigned int input_3;
    unsigned int the_answer;


      ///////////////////////////
     // Check and Set Variables int arg1 = atoi(argv[1]);
    ///////////////////////////

    // check length of input
    if ( argc != 4 ) {
        // Error message in English
        printf("argc = %d", argc);
        printf("incorrect number of input arguments: ");
        printf("After NAME.exe -> enter: ");
        printf("1. first number (int), 2. second number (int)");

        return EXIT_FAILURE;
        }

    // 1st input is the target row
    // pseudocode: input_1 = argv[2]
    sscanf(argv[1], "%u", &input_1);

    // 2nd input is the target column
    // pseudocode: input_2 = argv[3]
    sscanf(argv[2], "%u", &input_2);

    // 3rd input is the target column
    // pseudocode: input_3 = argv[3]
    sscanf(argv[3], "%u", &input_3);


      /////////////////
     // Code & Print
    /////////////////

    the_answer = input_1 | input_2;
    printf("or | answer = %u ", the_answer);

    printf("\\n");

    the_answer = input_1 & input_2;
    printf("and & answer = %u", the_answer);

    printf("\\n");

    the_answer = input_1 ^ input_2;
    printf("xor ^ answer = %u", the_answer);

    printf("\\n");

    the_answer = input_1 >> input_2;
    printf("right shift >> answer = %u", the_answer);

      ////////////
     // Finish //
    ////////////

    return 0;
}
"""

####################################
# Make it: Make your .c source file
####################################
with open('main.c', "w") as file_object:
   # write file content
   file_object.write( c_source_code_string )

#################################
# Compile your c executible file
#################################
# inspection
print("Compile: ")

# !gcc -o program.exe main.c

##########################################
# List Files in Current Working Directory
##########################################

# inspection
print("\nList Files (ls): ")

# !ls

#############################
# Run your c executible file
#############################
# inspection
print("\nRun: ")

# !./program.exe 5 1 3
# Out:
# Compile:
#
# List Files (ls):
# demo.csv  executable.exe  main.c  program.exe  sample_data  source_file.c
#
# Run:
# or | answer = 5
# and & answer = 1
# xor ^ answer = 4
# right shift >> answer = 2

# %%
input_1 = 5
input_2 = 12

# check
# !cpplint main.c; splint main.c; gcc -o program.exe main.c

# run
# !./program.exe input_1 input_2
# Out:
# Done processing main.c
# Splint 3.1.2 --- 20 Feb 2018
#
# main.c: (in function main)
# main.c:40:5: Return value (type int) ignored: sscanf(argv[1], ...
#   Result returned by function call is not used. If this is intended, can cast
#   result to (void) to eliminate message. (Use -retvalint to inhibit warning)
# main.c:44:5: Return value (type int) ignored: sscanf(argv[2], ...
#
# Finished checking --- 2 code warnings
# | the_answer = 3026476477

# %% [markdown]
# # Lint

# %%
# !pip install cpplint
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: cpplint in /usr/local/lib/python3.7/dist-packages (1.6.1)

# %%
# !cpplint main.c
# Out:
# Done processing main.c

# %%
# !splint main.c
# Out:
# Splint 3.1.2 --- 20 Feb 2018
#
# main.c: (in function main)
# main.c:40:5: Return value (type int) ignored: sscanf(argv[1], ...
#   Result returned by function call is not used. If this is intended, can cast
#   result to (void) to eliminate message. (Use -retvalint to inhibit warning)
# main.c:44:5: Return value (type int) ignored: sscanf(argv[2], ...
#
# Finished checking --- 2 code warnings
